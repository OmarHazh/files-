# %% [markdown]
# <h1 align='center'>  <font size = '6' color='red'> Advanced Data Analysis and Visualization  <font> </h1>
#
#
# <br>
# <center><h2> <center> <font color='green'> CHAPTER 3: Data Collection
# Structures <font> </h2> </center>
# <br>
#
# ![logo.png](attachment:logo.png)
#
#
# <br>
# <!-- <center align="left"> Developed for the MSc Program in Data Science  </center> -->
#
# <center align="left"> Ala-too International University </center>
#
#   <center align="left">    <center align="left"><center align="left"> <font color='dark blue'><font style= 'bold' size='3' color='dark'>  Instructor: Dr. Remudin Reshid MEKURIA <font> </center>

# %%
import calendar
calendar.prcal(2025)
# Out:
#                                   2025
#
#       January                   February                   March
# Mo Tu We Th Fr Sa Su      Mo Tu We Th Fr Sa Su      Mo Tu We Th Fr Sa Su
#        1  2  3  4  5                      1  2                      1  2
#  6  7  8  9 10 11 12       3  4  5  6  7  8  9       3  4  5  6  7  8  9
# 13 14 15 16 17 18 19      10 11 12 13 14 15 16      10 11 12 13 14 15 16
# 20 21 22 23 24 25 26      17 18 19 20 21 22 23      17 18 19 20 21 22 23
# 27 28 29 30 31            24 25 26 27 28            24 25 26 27 28 29 30
#                                                     31
#
#        April                      May                       June
# Mo Tu We Th Fr Sa Su      Mo Tu We Th Fr Sa Su      Mo Tu We Th Fr Sa Su
#     1  2  3  4  5  6                1  2  3  4                         1
#  7  8  9 10 11 12 13       5  6  7  8  9 10 11       2  3  4  5  6  7  8
# 14 15 16 17 18 19 20      12 13 14 15 16 17 18       9 10 11 12 13 14 15
# ...

# %% [markdown]
# Lists, dictionaries, tuples, series, data frames, and panels are Python data
# collection structures that can be used to maintain a collection of data.

# %% [markdown]
# # Lists

# %% [markdown]
# A list is a sequence of values of any data type that can be accessed
# forward or backward.A Python list is enclosed between a
# square brackets ([]), and elements are stored in the index based on a
# starting index of 0.

# %%
List1 = [1, 24, 76]
print (List1)
# Out:
# [1, 24, 76]

# %%
print(List1[0])
# Out:
# 1

# %%
colors=['red','black','white']
print(colors[2])
# Out:
# white

# %%
mix=['red', 24, 98.6]
print (mix)
# Out:
# ['red', 24, 98.6]

# %%
nested= [ 1, [5, 6], 7]

# %%
print (nested)
# Out:
# [1, [5, 6], 7]

# %%
print ([])
# Out:
# []

# %% [markdown]
# # Accessing Values in Lists

# %%
list1= ['Egypt', 'chemistry', 2017, 2018]
list2= [1, 2, 3, [4, 5],5656,4,4,4,4 ]
list3= ["a", 3.7, '330', "Omar"]
print(list1[2])
# Out:
# 2017

# %%
print(list2 [:3])
# Out:
# [1, 2, 3]

# %%
print(list2 [3:])
# Out:
# [[4, 5], 5656, 4, 4, 4, 4]

# %%
print(list3 [-3:-1])
# Out:
# [3.7, '330']

# %%
print(list3[-1])
# Out:
# Omar

# %%
print(list3[:-1])
# Out:
# ['a', 3.7, '330']

# %% [markdown]
# # Adding and Updating Lists

# %% [markdown]
# You can update single or multiple elements of lists by giving the slice on
# the left side of the assign operator, and you can add elements to a list with
# the append() method,

# %%
courses=["OOP","Networking","MIS","Project"]
students=["Ahmed", "Ali","Salim", "Abdullah", "Salwa"]
OOP_marks = [65, 85, 92]
OOP_marks.append(50)
OOP_marks.append(77)

# %%
print (OOP_marks[:])
# Out:
# [65, 85, 92, 50, 77]

# %%
OOP_marks[0]=70
OOP_marks[1]=45
list1 = [88, 93]
OOP_marks.extend(list1)
list
print(OOP_marks[ : ])
# Out:
# [70, 45, 92, 50, 77, 88, 93]

# %% [markdown]
# # Deleting List Elements

# %%
OOP_marks = [70, 45, 92, 50, 77, 45]
print (OOP_marks)
del OOP_marks[0] # delete an element using del
print (OOP_marks)
OOP_marks.remove (45) # remove an element using remove() method
print (OOP_marks)
OOP_marks.pop (2) # remove an element using pop() method
print (OOP_marks)
# Out:
# [70, 45, 92, 50, 77, 45]
# [45, 92, 50, 77, 45]
# [92, 50, 77, 45]
# [92, 50, 45]

# %% [markdown]
# # Basic List Operations

# %%
print (len([5, "Datascience", 3]))
# find the list length.
print ([1, 3, 1] + ["Datascience", 5, 6]) # concatenate lists.
print (['Eg!'] * 4) # repeat an element in a list.
print (4 in [1, 2, 3])# check if element in a list
for x in [1, 2, 3]:print (x, end=' ') # tr
# Out:
# 3
# [1, 3, 1, 'Datascience', 5, 6]
# ['Eg!', 'Eg!', 'Eg!', 'Eg!']
# False
# 1 2 3

# %% [markdown]
# # List Functions

# %%
tickets = [3, 41, 12, 9, 74, 15]
print (tickets)
print (len(tickets))
print (max(tickets))
print (min(tickets))
print (sum(tickets))
print (sum(tickets)/len(tickets))
# Out:
# [3, 41, 12, 9, 74, 15]
# 6
# 74
# 3
# 154
# 25.666666666666668

# %% [markdown]
# # List Sorting and Traversing

# %%
seq=(41, 12, 9, 74, 3, 15) # use sequence for creating a list
tickets=list(seq)
print (tickets) 
tickets.sort()
print (tickets)
print ("\nSorted list elements ")  
for ticket in tickets: print (tickets)
# Out:
# [41, 12, 9, 74, 3, 15]
# [3, 9, 12, 15, 41, 74]
#
# Sorted list elements
# [3, 9, 12, 15, 41, 74]
# [3, 9, 12, 15, 41, 74]
# [3, 9, 12, 15, 41, 74]
# [3, 9, 12, 15, 41, 74]
# [3, 9, 12, 15, 41, 74]
# [3, 9, 12, 15, 41, 74]

# %% [markdown]
# # Lists and Strings

# %% [markdown]
# Lists and Strings
# You can split a string into a list of characters. In addition, you can split a
# string into a list of words using the split() method. The default delimiter
# for the split() method is a white space. However, you can specify which
# characters to use as the word boundaries. For example, you can use a
# hyphen as a delimiter

# %% [markdown]
#  Converting a String into a List of Characters or Words

# %%
Word = 'Egypt'
List1 = list(Word)
print (List1)
# Out:
# ['E', 'g', 'y', 'p', 't']

# %%
Greeting= 'Welcome-to-Egypt'
List2 =Greeting.split("-")
print (List2)
# Out:
# ['Welcome', 'to', 'Egypt']

# %%
Greeting= 'Welcome-to-Egypt'
delimiter='-'
List2 =Greeting.split(delimiter)

# %%
print (List2)
# Out:
# ['Welcome', 'to', 'Egypt']

# %%
Greeting= 'Welcome to Bishkek'
List2 =Greeting.split()
print (List2)
# Out:
# ['Welcome', 'to', 'Bishkek']

# %%
print (List2[2])
# Out:
# Egypt

# %% [markdown]
# # Aliasing

# %% [markdown]
# The assign operator is dangerous if you don’t use it carefully. The
# association of a variable with an object is called a reference. In addition,
# an object with more than one reference and more than one name is called an alias.

# %%
#With Alias
a = [1, 2, 3]
b = a
print (a)
print (b)
# Out:
# [1, 2, 3]
# [1, 2, 3]

# %%
a.append(77)
print (a)
print (b)
# Out:
# [1, 2, 3, 77]
# [1, 2, 3, 77]

# %%
a is b
# Out:
# True

# %%
 b is a
# Out:
# True

# %%
#Without Alias

# %%
a = [1, 2, 3]
b = [1, 2, 3]
print (a)
print (b)
# Out:
# [1, 2, 3]
# [1, 2, 3]

# %%
a.append(77)
print (a)
print (b)
# Out:
# [1, 2, 3, 77]
# [1, 2, 3]

# %% [markdown]
# # Dictionaries

# %% [markdown]
# A dictionary is an unordered set of key-value pair; each key is separated
# from its value by a colon (:). The items (the pair) are separated by commas,
# and the whole thing is enclosed in curly braces ({}). In fact, an empty
# dictionary is written only with curly braces:. Dictionary keys should be
# unique and should be of an immutable data type such as string, integer, etc.

# %%
#Creating Dictionaries

Prices = {"Honda":40000, "Suzuki":50000,
"Mercedes":85000, "Nissan":35000, "Mitsubishi": 43000}
print (Prices)
# Out:
# {'Honda': 40000, 'Suzuki': 50000, 'Mercedes': 85000, 'Nissan': 35000, 'Mitsubishi': 43000}

# %% [markdown]
# # Tuples

# %% [markdown]
# A tuple is a sequence just like a list of immutable objects. The differences
# between tuples and lists are that the tuples cannot be altered; also, tuples
# use parentheses, whereas lists use square brackets.

# %%
#Creating Tuples
Names = ('Omar', 'Ali', 'Bahaa')
Marks = ( 75, 65, 95 )
print (Names[2])
print (Marks)
print (max(Marks))
# Out:
# Bahaa
# (75, 65, 95)
# 95

# %% [markdown]
# # Series

# %% [markdown]
# A series is defined as a one-dimensional labeled array capable of
# holding any data type (integers, strings, floating-point numbers, Python
# objects, etc.).
# SeriesX = pd.Series(data, index=index),
# Here, pd is a Pandas form, and data refers to a Python dictionary, an
# ndarray, or even a scalar value.

# %% [markdown]
# ### Creating a Series with index

# %%
import numpy as np
import pandas as pd
Series1 = pd.Series(np.random.randn(4), index=['a','b', 'c','d'])
print(Series1)
print(Series1.index)
# Out:
# a   -0.353250
# b    0.140037
# c   -0.590887
# d   -0.500682
# dtype: float64
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %% [markdown]
#  Creating a Series of Ndarray Data Without Labels

# %%
import numpy as np
import pandas as pd
Series2 = pd.Series(np.random.randn(6))
print(Series2)
print(Series2.index)
# Out:
# 0   -0.189998
# 1    0.228573
# 2   -0.399733
# 3    0.390438
# 4   -0.166208
# 5   -0.868260
# dtype: float64
# RangeIndex(start=0, stop=6, step=1)

# %%
print (" \n Series slicing ")
print (Series1[:3])
print ("\nIndex accessing")
print (Series1[[3,1,0]])
print ("\nSingle index")
x = Series1[0]
print (x)
# Out:
#
#  Series slicing
# a   -0.353250
# b    0.140037
# c   -0.590887
# dtype: float64
#
# Index accessing
# d   -0.500682
# b    0.140037
# a   -0.353250
# dtype: float64
#
# Single index
# -0.3532500044297549

# %% [markdown]
# # Sample Operations in a Series

# %%
print ("\nSeries Sample operations")
print ("\n Series values greater than the mean: %.4f" % Series1.mean())
print (Series1 [Series1> Series1.mean()])
print ("\n Series values greater than the Meadian:%.4f" % Series1.median())
print (Series1 [Series1> Series1.median()])
print ("\nExponential value ")
Series1Exp = np.exp(Series1)
print (Series1Exp)
# Out:
# Series Sample operations
#
#  Series values greater than the mean: -0.3262
# b    0.140037
# dtype: float64
#
#  Series values greater than the Meadian:-0.4270
# a   -0.353250
# b    0.140037
# dtype: float64
#
# Exponential value
# a    0.702402
# b    1.150316
# c    0.553836
# d    0.606117
# dtype: float64

# %% [markdown]
# # Creating a Series from a Dictionary

# %%
dict = {'m' : 2, 'y' : 2018, 'd' : 'Sunday'}
print ("\nSeries of non declared index")
SeriesDict1 = pd.Series(dict)
print(SeriesDict1)
print ("\nSeries of declared index")
SeriesDict2 = pd.Series(dict,index=['y', 'm', 'd','s']) 
print(SeriesDict2)
# Out:
# Series of non declared index
# m         2
# y      2018
# d    Sunday
# dtype: object
#
# Series of declared index
# y      2018
# m         2
# d    Sunday
# s       NaN
# dtype: object

# %% [markdown]
# # Altering a Series and Using the Get() Method

# %%
print ("\nUse the get and set methods to access" "a series values by index label\n")
SeriesDict2 = pd.Series(dict, index=['y', 'm', 'd','s']) 
print (SeriesDict2['y']) # Display the year
SeriesDict2['y']=1999
# change the year value
print (SeriesDict2)
# Display all dictionary values
#print (SeriesDict2.get('y')) # get specific value by its key Use the get and set methods to access a series valuesby index label
# Out:
# Use the get and set methods to accessa series values by index label
#
# <class 'dict'>
# y              1999
# m    <class 'dict'>
# d    <class 'dict'>
# s    <class 'dict'>
# dtype: object

# %% [markdown]
# Creating a Series from a Scalar Value
# If data is a scalar value, an index must be provided. The value will be
# repeated to match the length of index.

# %%
print ("\n CREATE SERIES FORM SCALAR VALUE ")
Scl = pd.Series([8,9,16,5], index=['a', 'b', 'c', 'd'])
print (Scl)
# Out:
#  CREATE SERIES FORM SCALAR VALUE
# a     8
# b     9
# c    16
# d     5
# dtype: int64

# %% [markdown]
# # Vectorized Operations and Label Alignment with Series
#
# Series operations automatically align the data based on label. Thus, you
# can write computations without giving consideration to whether the series
# involved have the same labels. If labels are not matches, it gives a missing
# value NaN.

# %% [markdown]
# Vectorizing Operations on a Series

# %%
SerX = pd.Series([1,2,3,4], index=['a', 'b', 'c', 'd'])
print ("Addition");
print( SerX + SerX)
print ("Addition with non-matched labels");
print (SerX[1:] + SerX[:-1])# SerX[1:] will have    b, c and  d ready to be added with 
                            # SerX[:-1] will have    c, b, a
print ("Multiplication");
print (SerX * SerX)

print ("Exponential");
print (np.exp(SerX))
# Out:
# Addition
# a    2
# b    4
# c    6
# d    8
# dtype: int64
# Addition with non-matched labels
# a    NaN
# b    4.0
# c    6.0
# d    NaN
# dtype: float64
# Multiplication
# a     1
# b     4
# c     9
# d    16
# dtype: int64
# Exponential
# a     2.718282
# b     7.389056
# c    20.085537
# d    54.598150
# dtype: float64

# %% [markdown]
# # Name Attribute
#
# You can name a series; also, you can alter a series.

# %% [markdown]
# Using a Series Name Attribute

# %%
std = pd.Series([77,89,65,90], name='StudentsMarks')
print (std.name)
print("old std:",std)
print()
std = std.rename("Marks")
print (std.name)
std
# Out:
# StudentsMarks
# old std: 0    77
# 1    89
# 2    65
# 3    90
# Name: StudentsMarks, dtype: int64
#
# Marks
# 0    77
# 1    89
# 2    65
# 3    90
# Name: Marks, dtype: int64

# %%
print (std)
# Out:
# 0    77
# 1    89
# 2    65
# 3    90
# Name: Marks, dtype: int64

# %% [markdown]
# <font color = red size = 6 > Next Week from here! <font>

# %% [markdown]
# # Data Frames

# %% [markdown]
# A data frame is a two-dimensional tabular labeled data structure with
# columns of potentially different types. A data frame can be created from
# numerous data collections such as the following:
# * A 1D ndarray, list, dict, or series
# * 2D Numpy ndarray
# * Structured or record ndarray
# * A series
# * Another data frame
#
# A data frame has arguments, which are an index (row labels) and columns (column labels).

# %% [markdown]
# # Creating Data Frames from a Dict of Series or Dicts

# %% [markdown]
# You can simply create a data frame from a dictionary of series; it’s also
# possible to assign an index. If there is an index without a value, it gives a
# NaN value,

# %% [markdown]
# # Creating a Data Frame from a Dict of Series

# %%
import pandas as pd
dict1 = {'one' : pd.Series([1., 2., 3.],
index=['a', 'b', 'c']),
'two' : pd.Series([1., 2., 3., 4.],
index=['a', 'b', 'c', 'd'])}
df = pd.DataFrame(dict1)
df
# Out:
#    one  two
# a  1.0  1.0
# b  2.0  2.0
# c  3.0  3.0
# d  NaN  4.0

# %%
# set index for the DataFrame
pd.DataFrame(dict1, index=['d', 'b', 'a'])
# Out:
#    one  two
# d  NaN  4.0
# b  2.0  2.0
# a  1.0  1.0

# %%
pd.DataFrame(dict1, index=['a', 'b'])
df = pd.DataFrame(dict1)
df
# Out:
#    one  two
# a  1.0  1.0
# b  2.0  2.0
# c  3.0  3.0
# d  NaN  4.0

# %%
# Control the labels appearance of the DataFrame
pd.DataFrame(dict1, index=['d', 'b', 'a'], columns=['two',
'three', 'one'])
# Out:
#    two three  one
# d  4.0   NaN  NaN
# b  2.0   NaN  2.0
# a  1.0   NaN  1.0

# %% [markdown]
# # Creating Data Frames from a Dict of Ndarrays/Lists

# %% [markdown]
# https://numpy.org/doc/stable/reference/generated/numpy.ndarray.html

# %% [markdown]
# When you create a data frame from an ndarray, the ndarrays must all be
# the same length. Also, the passed index should be of the same length as
# the arrays. If no index is passed, the result will be range(n), where n is the
# array length.

# %% [markdown]
# Creating a Data Frame from an Ndarray

# %%
# without index
ndarrdict = {'one' : [1., 2., 3., 4.],'two' :
[4., 3., 2., 1.]}
pd.DataFrame(ndarrdict)
# Out:
#    one  two
# 0  1.0  4.0
# 1  2.0  3.0
# 2  3.0  2.0
# 3  4.0  1.0

# %%
# Assign index
pd.DataFrame(ndarrdict, index=['a', 'b', 'c', 'd'])
# Out:
#    one  two
# a  1.0  4.0
# b  2.0  3.0
# c  3.0  2.0
# d  4.0  1.0

# %% [markdown]
# # Creating Data Frames from a Structured or Record Array

# %%
#Creating a Data Frame from a Record Array

import pandas as pd
import numpy as np
data = np.zeros((2,), dtype=[('A', 'i4'),('B', 'f4'),
('C', 'a10')])
data[:] = [(1,2.,'Hello'), (2,3.,"World")]
pd.DataFrame(data)
# Out:
#    A    B         C
# 0  1  2.0  b'Hello'
# 1  2  3.0  b'World'

# %% [markdown]
# creates a data frame by first specifying the data types of each
# column and then the values of each row. ('A', 'i4') determines the
# column label and its data type as integers, ('B', 'f4') determines the
# label as B and the data type as float, and finally ('C', 'a10') assigns the
# label C and data type as a string with a maximum of ten characters.

# %%
pd.DataFrame(data, index=['First', 'Second'])
# Out:
#         A    B         C
# First   1  2.0  b'Hello'
# Second  2  3.0  b'World'

# %%
pd.DataFrame(data, columns=['C', 'A', 'B'])
# Out:
#           C  A    B
# 0  b'Hello'  1  2.0
# 1  b'World'  2  3.0

# %% [markdown]
# # Creating Data Frames from a List of Dicts

# %%
#Creating a Data Frame from a List of Dictionaries
data2 = [{'A ': 1, 'B ': 2}, {'A': 3, 'B': 10, 'C': 20},{'A':11,'B':12,'C':21}]
pd.DataFrame(data2)
# Out:
#     A    B      A     B     C
# 0  1.0  2.0   NaN   NaN   NaN
# 1  NaN  NaN   3.0  10.0  20.0
# 2  NaN  NaN  11.0  12.0  21.0

# %%
#pd.DataFrame(data2, index=['First', 'Second'])

# %%
pd.DataFrame(data2, columns=['A', 'B'])
# Out:
#       A     B
# 0   NaN   NaN
# 1   3.0  10.0
# 2  11.0  12.0

# %% [markdown]
# # Creating Data Frames from a Dict of Tuples

# %% [markdown]
# Another method to create a multi-indexed data frame is to pass a
# dictionary of tuples,

# %%
#Creating a Data Frame from a Dictionary of Tuples
# Let us see this step by step
pd.DataFrame({('a'): {('A'): 1 }})
# Out:
#    a
# A  1

# %%
pd.DataFrame({('a', 'b'): {('A', 'B'): 1 }})
# Out:
#      a
#      b
# A B  1

# %%
pd.DataFrame({('a', 'b'): {('A', 'B'): 1, ('A', 'C'): 2}})
# Out:
#      a
#      b
# A B  1
#   C  2

# %%
#Creating a Data Frame from a Dictionary of Tuples

pd.DataFrame({('a', 'b'): {('A', 'B'): 1, ('A', 'C'): 2},
('a', 'a'): {('A', 'C'): 3, ('A','B'): 4},
('a', 'c'): {('A', 'B'): 5, ('A','C'): 6},
('b', 'a'): {('A', 'C'): 7, ('A','B'): 8},
('b', 'b'): {('A', 'D'): 9, ('A','B'): 10}})
# Out:
#        a              b
#        b    a    c    a     b
# A B  1.0  4.0  5.0  8.0  10.0
#   C  2.0  3.0  6.0  7.0   NaN
#   D  NaN  NaN  NaN  NaN   9.0

# %% [markdown]
# # Selecting, Adding, and Deleting Data Frame Columns

# %% [markdown]
# Once you have a data frame, you can simply add columns, remove
# columns, and select specific columns.
# **The follwoing example demonstrates how to
# alter a data frame and its related operations.**

# %%
# DATAFRAME COLUMN SELECTION, ADDITION, DELETION
ndarrdict = {'one' : [1., 2., 3., 4.], 'two' :
[4., 3., 2., 1.]}
df = pd.DataFrame(ndarrdict, index=['a', 'b', 'c', 'd'])
df
# Out:
#    one  two
# a  1.0  4.0
# b  2.0  3.0
# c  3.0  2.0
# d  4.0  1.0

# %%
df['three'] = df['one'] * df['two'] 
# Here we are adding a new column by multiplying values of column 1 with that of column 2
df['flag'] = df['one'] > 2  
#Here we are adding a column which gives boolean output upon comparing with an integer 2
df
# Out:
#    one  two  three   flag
# a  1.0  4.0    4.0  False
# b  2.0  3.0    6.0  False
# c  3.0  2.0    6.0   True
# d  4.0  1.0    4.0   True

# %% [markdown]
# * You can insert a scalar value to a data frame; it will naturally be propagated to fill the column.
# * To delete a column, you can use the del or pop method, as shown below:

# %%
#Adding a Column Using a Scalar and Assigning to a Data Frame
df['Filler'] = 'HCT'
df['Slic'] = df['one'][:2] 
#note: this will take only the first two values of the first column, thus others become NaN
df
# Out:
#    one  two  three   flag Filler  Slic
# a  1.0  4.0    4.0  False    HCT   1.0
# b  2.0  3.0    6.0  False    HCT   2.0
# c  3.0  2.0    6.0   True    HCT   NaN
# d  4.0  1.0    4.0   True    HCT   NaN

# %%
# Delete columns
del df['two'] #this deletes second column (here we se 'del')
Three = df.pop('three') # this deletes third column (here we use 'pop')
df

# %% [markdown]
# **By default, columns get inserted at the end. However, you can use
# the insert() function to insert at a particular location in the columns, as
# shown below:**

# %%
df.insert(1, 'bar', df['one'])
df

# %% [markdown]
# # Assigning New Columns in Method Chains

# %% [markdown]
# A data frame has an assign() method that allows you to easily create new
# columns that are potentially derived from existing columns. Also, you can
# change values of specific columns by altering the columns and making the
# necessary operations, as in column A given below

# %%
#Using the assign() Method to Add a Derived Column
import numpy as np
import pandas as pd
df = pd.DataFrame({"A": [1, 2, 3], "B": [4, 5, 6]})
df = df.assign(C=lambda x: x['A'] + x['B']) #adding column A and B to creat column C
df = df.assign( D=lambda x: x['A'] + x['C']) #adding column A and C to creat column D
df
# Out:
#    A  B  C   D
# 0  1  4  5   6
# 1  2  5  7   9
# 2  3  6  9  12

# %%
# Question: What is this doing?
df = df.assign( A=lambda x: x['A'] *2)
df
# Out:
#    A  B  C   D
# 0  2  4  5   6
# 1  4  5  7   9
# 2  6  6  9  12

# %% [markdown]
# ![df.png](attachment:df.png)

# %% [markdown]
# ![df.png](attachment:df.png)

# %% [markdown]
# # Indexing and Selecting Data Frames

# %% [markdown]
# * To select column use df[col] in Series
# * To select row by label use df.loc[label] in Series
# * To select row by integer location use df.iloc[loc] in Series

# %% [markdown]
# * To slice rows use df[5:10] in Data frame
# * To select rows by Boolean vector use df[bool_vec] in Data frame

# %% [markdown]
# **Data Frame Row and Column Selections**

# %%
df
# Out:
#    A  B  C   D
# 0  2  4  5   6
# 1  4  5  7   9
# 2  6  6  9  12

# %%
df['B'] #column B is selected
# Out:
# 0    4
# 1    5
# 2    6
# Name: B, dtype: int64

# %%
#Operations on Data Frames
df1 = pd.DataFrame({"A": [1, 2, 3], "B": [4, 5, 6]})
df2 = pd.DataFrame({"A": [7, 4, 6], "B": [10, 4, 15]})
print (df1)
print()
print(df2)
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6
#
#    A   B
# 0  7  10
# 1  4   4
# 2  6  15

# %%
#Question: What does df1 + df2 and df1 - df2 give?
#df1 + df2
#df1 - df2
# Out:
#    A   B
# 0  8  14
# 1  6   9
# 2  9  21

# %%
# You can also pick a particular row with iloc
# for eg. here the third row of df1 will be subtructed from each of the rows of df2
df2 - df1.iloc[2]
# Out:
#    A  B
# 0  4  4
# 1  1 -2
# 2  3  9

# %%
#Question: What does df2*2 + 1 will give?

# %% [markdown]
# **Transposing a Data Frame**

# %% [markdown]
# You can transpose a data frame using the T operator, as shown below

# %%
df2[:].T
# Out:
#     0  1   2
# A   7  4   6
# B  10  4  15

# %% [markdown]
# # Data Frame Interoperability with Numpy Functions

# %% [markdown]
# You can implement matrix operations using the dot method on a data frame. For example, you can implement matrix multiplication as in below

# %%
df1
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
#Matrix Multiplications
#for eg. Matrix Multiplications df1 with itself can be written as:
df1.T.dot(df1)
# Out:
#     A   B
# A  14  32
# B  32  77

# %%
df1.T.dot(df2) #for eg. Matrix Multiplications df1 with df2:
# Out:
#     A    B
# A  33   63
# B  84  150

# %%
df2.T.dot(df1)#for eg. Matrix Multiplications df2 with df1:
# As you may see matrix multiplication is not commutative AB is different from BA except for some matrices
# Out:
#     A    B
# A  33   84
# B  63  150

# %% [markdown]
# # Panels

# %% [markdown]
# A panel is a container for three-dimensional data; it’s somewhat less
# frequently used by Python programmers.
#
# A panel creation has three main attributes.
# * items: axis 0; each item corresponds to a data frame contained inside
# * major_axis: axis 1; it is the index (rows) of each of the data frames
# * minor_axis: axis 2; it is the columns of each of the data frames

# %% [markdown]
# This is removed in the new versions of pandas later than 0.25

# %% [markdown]
# # Summary
#
# Here’s a recap of what was covered:
# – How to maintain a collection of data in different forms
#
# – How to create lists and how to manipulate list content
#
# – What a dictionary is and the purpose of creating a dictionary as a data container
#
# – How to create tuples and what the difference is between
# tuple data structure and dictionary structure, as well as the
# basic tuple operations
#
# – How to create a series from other data collection forms
#
# – How to create data frames from different data collection
# structures and from another data frame

# %% [markdown]
# # Exercises
#
# 1. Write a program to create a list of names; then
# define a function to display all the elements in
# the received list. Call the function to execute its
# statements and display all names in the list.
#
#
# 2. Write a program to compare tuples of integers and
# tuples of strings.
#
# 3. Write a program to create a series to maintain three
# students’ names and GPA values.
#
# 4. Write a program to create a data frame to maintain
# three students’ names associated with their grades
# in three courses and then add a new column named
# Mean to maintain the calculated mean mark per
# course. Display the final data frame.
